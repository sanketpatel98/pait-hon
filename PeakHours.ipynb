# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
data = pd.read_csv('C:\\Users\\Sanket\\Desktop\\new_data\\2010.csv')

# %%
beans = []
for i in range(0,2400,100):
    beans.append(i)
plt.hist(data['DEP_TIME'],beans,histtype='bar',rwidth=0.8)
# PEAK HOURS FOR DEPARTURE : 07:00 A.M - 08:00 P.M
# Out:
# (array([2.0350e+03, 8.2700e+02, 2.4200e+02, 5.9000e+01, 4.3600e+02,
#         2.4337e+04, 6.0253e+04, 6.2241e+04, 6.7384e+04, 6.3642e+04,
#         6.3037e+04, 6.7122e+04, 6.2759e+04, 6.6087e+04, 6.4522e+04,
#         6.1272e+04, 6.7235e+04, 6.6641e+04, 6.0957e+04, 5.9277e+04,
#         3.8897e+04, 2.9421e+04, 1.5209e+04]),
#  array([   0,  100,  200,  300,  400,  500,  600,  700,  800,  900, 1000,
#         1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100,
#         2200, 2300]),
#  <a list of 23 Patch objects>)

# %%
plt.hist(data['ARR_TIME'],beans,histtype='bar',rwidth=0.8)
# PEAK HOURS FOR ARRIVAL : 09:00 A.M - 11:00 P.M
# Out:
# (array([ 9790.,  2326.,   732.,   353.,  1437.,  4017.,  9874., 32550.,
#         47893., 56488., 64129., 62055., 63751., 63979., 62173., 64685.,
#         68929., 66269., 66800., 62761., 64840., 55812., 45536.]),
#  array([   0,  100,  200,  300,  400,  500,  600,  700,  800,  900, 1000,
#         1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100,
#         2200, 2300]),
#  <a list of 23 Patch objects>)

# %%
plt.hist(data['ARR_DELAY'],beans,histtype='bar',rwidth=0.8)
# Out:
# (array([3.93487e+05, 2.00500e+04, 3.45000e+03, 7.94000e+02, 2.06000e+02,
#         7.40000e+01, 4.10000e+01, 2.60000e+01, 1.50000e+01, 1.60000e+01,
#         1.50000e+01, 7.00000e+00, 5.00000e+00, 2.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00]),
#  array([   0,  100,  200,  300,  400,  500,  600,  700,  800,  900, 1000,
#         1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100,
#         2200, 2300]),
#  <a list of 23 Patch objects>)

# %%
plt.hist(data['DEP_DELAY'],beans,histtype='bar',rwidth=0.8)
# Out:
# (array([4.31594e+05, 1.94840e+04, 3.47400e+03, 7.46000e+02, 2.21000e+02,
#         7.00000e+01, 4.00000e+01, 2.70000e+01, 1.80000e+01, 1.70000e+01,
#         1.40000e+01, 1.00000e+01, 3.00000e+00, 2.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00]),
#  array([   0,  100,  200,  300,  400,  500,  600,  700,  800,  900, 1000,
#         1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100,
#         2200, 2300]),
#  <a list of 23 Patch objects>)

# %%
plt.scatter(data['ARR_TIME'],data['ARR_DELAY'])

# %%
sns.barplot(x=data["DEP_TIME"], y=data["DEP_DELAY"], data=data)

# %%
bins = [0, 500, 1000, 1500, 2000]
ax = plt.subplot()
ax.bar(data["DEP_TIME"], data["DEP_DELAY"], width=100)
ax.set_xticks(bins)
plt.show()
