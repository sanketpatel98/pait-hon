# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('E:\\project_data\\final2009.csv')

# %%
df.head()
# Out:
#       FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0  2009-01-01         XE               1204    DCA  EWR          1100
# 1  2009-01-01         XE               1206    EWR  IAD          1510
# 2  2009-01-01         XE               1207    EWR  DCA          1100
# 3  2009-01-01         XE               1208    DCA  EWR          1240
# 4  2009-01-01         XE               1209    IAD  EWR          1715
#
#    DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  ...  CRS_ELAPSED_TIME  \
# 0    1058.0       -2.0      18.0      1116.0  ...              62.0
# 1    1509.0       -1.0      28.0      1537.0  ...              82.0
# 2    1059.0       -1.0      20.0      1119.0  ...              70.0
# 3    1249.0        9.0      10.0      1259.0  ...              77.0
# 4    1705.0      -10.0      24.0      1729.0  ...             105.0
#
#    ACTUAL_ELAPSED_TIME  AIR_TIME  DISTANCE  CARRIER_DELAY  WEATHER_DELAY  \
# ...

# %%
df.OP_CARRIER.unique()
# Out:
# array(['XE', 'YV', 'NW', 'OH', 'OO', 'UA', 'US', 'WN', 'EV', 'F9', 'FL',
#        'HA', 'MQ', '9E', 'AA', 'AS', 'B6', 'CO', 'DL'], dtype=object)

# %%
df["FL_DATE"] = pd.to_datetime(df["FL_DATE"])

# %%
st="2009-01-01"
ed="2009-01-30"
temp = (df["FL_DATE"] > st) & (df["FL_DATE"] <= ed)
df1 = df.loc[temp]

# %%
df1
# Out:
#           FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 16237  2009-01-02         9E               2102    AUS  IND          1655
# 16238  2009-01-02         9E               2103    IND  AUS          1445
# 16239  2009-01-02         9E               2108    OKC  MSP           700
# 16240  2009-01-02         9E               2109    MSP  OKC          2130
# 16241  2009-01-02         9E               2110    OKC  MSP          1745
# ...           ...        ...                ...    ...  ...           ...
# 518153 2009-01-30         CO               1883    STT  EWR          1515
# 518154 2009-01-30         CO               1884    EWR  STT           915
# 518155 2009-01-30         CO               1889    IAH  SMF          1827
# 518156 2009-01-30         CO               1890    SNA  IAH           855
# 518157 2009-01-30         CO               1893    SMF  IAH          1225
#
#         DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  ...  CRS_ELAPSED_TIME  \
# ...

# %%
df1.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-2b3d44c0d3c8> in <module>
# ----> 1 df1.unique()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
df['OP_CARRIER'].replace({
    'UA':'United Airlines',
    'AS':'Alaska Airlines',
    '9E':'Endeavor Air',
    'B6':'JetBlue Airways',
    'EV':'ExpressJet',
    'F9':'Frontier Airlines',
    'G4':'Allegiant Air',
    'HA':'Hawaiian Airlines',
    'MQ':'Envoy Air',
    'NK':'Spirit Airlines',
    'OH':'PSA Airlines',
    'OO':'SkyWest Airlines',
    'VX':'Virgin America',
    'WN':'Southwest Airlines',
    'YV':'Mesa Airline',
    'YX':'Republic Airways',
    'AA':'American Airlines',
    'DL':'Delta Airlines',
    'NW':'Northwest Airlines',
    'US':'US Airways',
    'FL':'AirTran',
    'CO':'Continental Airlines',
    'XE':'ExpressJet Airlines'
},inplace=True)

# %%
df.OP_CARRIER.unique()
# Out:
# array(['ExpressJet Airlines', 'Mesa Airline', 'Northwest Airlines',
#        'PSA Airlines', 'SkyWest Airlines', 'United Airlines',
#        'US Airways', 'Southwest Airlines', 'ExpressJet',
#        'Frontier Airlines', 'AirTran', 'Hawaiian Airlines', 'Envoy Air',
#        'Endeavor Air', 'American Airlines', 'Alaska Airlines',
#        'JetBlue Airways', 'Continental Airlines', 'Delta Airlines'],
#       dtype=object)

# %%
df.to_csv('E:\\project_data\\final2009_extend.csv')

# %%
df.OP_CARRIER
# Out:
# 0                 XE
# 1                 XE
# 2                 XE
# 3                 XE
# 4                 XE
#              ...
# 999993    US Airways
# 999994    US Airways
# 999995    US Airways
# 999996    US Airways
# 999997    US Airways
# Name: OP_CARRIER, Length: 999998, dtype: object

# %%
s=pd.Series(df.OP_CARRIER)

# %%
s.drop(labels='XE',axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-fd2e04e9d759> in <module>
# ----> 1 s.drop(labels='XE',axis=0)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4321             level=level,
#    4322             inplace=inplace,
# -> 4323             errors=errors,
#    4324         )
#    4325
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
df.drop(labels='XE',level=1)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-18-24e59831dbaa> in <module>
# ----> 1 df.drop(labels='XE',level=1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
df.drop('XE')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-fc85e28c178b> in <module>
# ----> 1 df.drop('XE')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
df
# Out:
#           FL_DATE  OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0      2009-01-01          XE               1204    DCA  EWR          1100
# 1      2009-01-01          XE               1206    EWR  IAD          1510
# 2      2009-01-01          XE               1207    EWR  DCA          1100
# 3      2009-01-01          XE               1208    DCA  EWR          1240
# 4      2009-01-01          XE               1209    IAD  EWR          1715
# ...           ...         ...                ...    ...  ...           ...
# 999993 2009-02-27  US Airways                821    LGA  CLT          1000
# 999994 2009-02-27  US Airways               1233    LGA  CLT          1115
# 999995 2009-02-27  US Airways               1455    LGA  CLT           630
# 999996 2009-02-27  US Airways               1489    LGA  CLT          1855
# 999997 2009-02-27  US Airways               1573    LGA  CLT          1259
#
# ...
