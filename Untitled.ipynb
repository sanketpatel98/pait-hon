# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt
from matplotlib import style as sty

# %%
sty.use('ggplot')
plt.plot([1,2,4],[4,5,6],'g',label='line one',linewidht=5)
plt.plot([2,2,5],[3,6,1],'b',label='line two',linewidht=5)
plt.title('info')
plt.ylabel('Y axix')
plt.xlabel('X axix')
plt.legend()
plt.grid(True,color='k')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-f05b3d83965b> in <module>()
#       1 sty.use('ggplot')
# ----> 2 plt.plot([1,2,4],[4,5,6],'g',label='line one',linewidht=5)
#       3 plt.plot([2,2,5],[3,6,1],'b',label='line two',linewidht=5)
#       4 plt.title('info')
#       5 plt.ylabel('Y axix')
#
# C:\Users\Sanket\Anaconda2\lib\site-packages\matplotlib\pyplot.pyc in plot(*args, **kwargs)
#    3361                       mplDeprecation)
#    3362     try:
# -> 3363         ret = ax.plot(*args, **kwargs)
#    3364     finally:
#    3365         ax._hold = washold
#
# C:\Users\Sanket\Anaconda2\lib\site-packages\matplotlib\__init__.pyc in inner(ax, *args, **kwargs)
#    1865                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1866                         RuntimeWarning, stacklevel=2)
# ...
